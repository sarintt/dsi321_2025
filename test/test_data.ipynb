# %%
import pandas as pd
from config.path_config import lakefs_s3_path
import os

# %%
df = pd.read_csv("/Users/use/Documents/dsi321_2025/data/from_prefect/data.csv")
repo_name = "tweets-repo"
branch_name = "main"
path = "tweets.parquet"
lakefs_s3_path = f"s3://{repo_name}/{branch_name}/{path}"
def data_from_lakefs(lakefs_endpoint: str = "http://localhost:8001/", columns: list[str] = None):
    storage_options = {
        "key": os.getenv("ACCESS_KEY"),
        "secret": os.getenv("SECRET_KEY"),
        "client_kwargs": {
            "endpoint_url": lakefs_endpoint
        }
    }
    df = pd.read_parquet(
        lakefs_s3_path,
        columns=columns,
        storage_options=storage_options,
        engine='pyarrow',
    )
    return df

# %%
df = df.rename(columns={'postTimeRaw': 'timestamp'})
df['category'] = df['category'].astype('string')
df['tag'] = df['tag'].astype('string')
df['username'] = df['username'].astype('string')
df['tweetText'] = df['tweetText'].astype('string')
df['year'] = df['year'].astype('int32')
df['month'] = df['month'].astype('int32')
df['day'] = df['day'].astype('int32')
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['timestamp'] = df['timestamp'].dt.tz_localize('UTC')
df['scrapeTime'] = pd.to_datetime(df['scrapeTime'])
df['scrapeTime'] = df['scrapeTime'].dt.tz_localize('UTC')
df.to_parquet('../data/data.parquet', engine='pyarrow')
df.dtypes
# Out:
# category           string[python]
# tag                string[python]
# username           string[python]
# tweetText          string[python]
# timestamp     datetime64[ns, UTC]
# scrapeTime    datetime64[ns, UTC]
# year                        int32
# month                       int32
# day                         int32
# dtype: object

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1336 entries, 0 to 1335
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   category    1336 non-null   object
#  1   tag         1336 non-null   object
#  2   username    1336 non-null   object
#  3   tweetText   1336 non-null   object
#  4   timestamp   1336 non-null   object
#  5   scrapeTime  1336 non-null   object
#  6   year        1336 non-null   int32
#  7   month       1336 non-null   int32
#  8   day         1336 non-null   int32
# dtypes: int32(3), object(6)
# memory usage: 78.4+ KB
#      category                   tag         username  \
# 0  ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก  @Kt123123123123
# 1  ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก     @somuensojai
# 2  ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก   @jaeminjenfffy
# 3  ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก      @mankheuthe
# 4  ธรรมศาสตร์  #ธรรมศาสตร์ช้างเผือก    @green_thai04
#
# ...

# %%
lakefs_endpoint = "http://localhost:8001/"
storage_options = {
    "key": os.getenv("ACCESS_KEY"),
    "secret": os.getenv("SECRET_KEY"),
    "client_kwargs": {
        "endpoint_url": lakefs_endpoint
    }
}
repo_name = "tweets-repo21"
branch_name = "main"
path = "tweets.parquet"
lakefs_s3_path = f"local://{repo_name}/{branch_name}/{path}"
data = pd.read_parquet(
    lakefs_s3_path,
    storage_options=storage_options,
    engine='pyarrow',
)

data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 13
#      11 path = "tweets.parquet"
#      12 lakefs_s3_path = f"local://{repo_name}/{branch_name}/{path}"
# ---> 13 data = pd.read_parquet(
#      14     lakefs_s3_path,
#      15     storage_options=storage_options,
#      16     engine='pyarrow',
#      17 )
#      19 data.head()
#
# File ~/Documents/dsi321_2025/.venv/lib/python3.13/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     664     use_nullable_dtypes = False
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
# ...
